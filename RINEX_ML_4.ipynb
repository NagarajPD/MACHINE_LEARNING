# %%
#EXPLORATORY DATA ANALYSIS(EDA) - WE FINMD DIFFERENT INSIGHTS AND WE GET CONCLUSIONS

# %%
#Dataset-https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230904%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230904T170712Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
#dataset- raw unprocessed collection of data
#data frame-tabled data(data in form of data)

# %%
#1 take the data and create the dataset
import pandas as pd
df=pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230904%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230904T170712Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep='\t')

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.shape #(59,7) -59rows and 7 columns
# Out:
# (59, 7)

# %%
df.size  #413 is the total number of elements in dataframe
# Out:
# 413

# %%
df.info() #it gets all the info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#object datadype in python is nothing but string

# %%
#to find out the count null values or missing values
df.isnull().sum()  #our data set doesnt havce
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
#slicing
#slice row indexs from 25 to43
#df[inclusive:execlusive]
df[25:44]

# %%
#slice row indexs from 25 to 43 and column index 0 and 1
#df.iloc[row slicing,column slicing]
df.iloc[25:44,0:2]

# %%
#i want know the excat count of uniuque fruit name
df['fruit_name'].nunique()
# Out:
# 4

# %%
#I want the excat name of the fruits present in data base
fname=df['fruit_name'].unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#i want the exacat count of each and every fruit
fsize=df.groupby('fruit_name',sort=False).size()
#all the fruit name are sorted in albahetical order
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
#visiualisation
import matplotlib.pyplot as plt

# %%
plt.bar(fname,fsize,color=['red','b','orange','black'])
# Out:
# <BarContainer object of 4 artists>

# %%
#EDA MODEL 2 (DATASET 2)
df=pd.read_csv('/content/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape  # 891 rows and 12 columns
# Out:
# (891, 12)

# %%
df.size # total no of elements
# Out:
# 10692

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#the excat count pf null values in each column
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#i want knoe the excat no of unique elements in each column
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
#how many have sirvived how many have died
df.groupby('Survived').size()
# Out:
# Survived
# 0    549
# 1    342
# dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#how many males and how many felames are present in titanic
df.groupby('Sex').size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#I want to find out how many males and how many females have sirvieved and not sirvieved
df.groupby(['Sex','Survived']).size()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# dtype: int64
